# %%
import pandas as pd
import numpy as np

# %%
nba_data = pd.read_csv("season_stats.txt", header=1)

# %%
nba_data
# Out:
#     Rk   G        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA  ...  FT.1  \
# 0    1   1  2019-10-23        NaN  SAC   W  124     95  49   98  ...    17
# 1    2   2  2019-10-25          @  DEN   L  107    108  34   86  ...    29
# 2    3   3  2019-10-26        NaN  LAC   W  130    122  43   86  ...    31
# 3    4   4  2019-10-28        NaN  UTA   L   95     96  33   80  ...    32
# 4    5   5  2019-10-30          @  GSW   W  121    110  44   96  ...    30
# ..  ..  ..         ...        ...  ...  ..  ...    ...  ..  ...  ...   ...
# 63  64  64  2020-03-08        NaN  MIL   W  140    131  47   85  ...    16
# 64  65  65  2020-03-10          @  POR   L  105    121  35   87  ...    14
# 65  66  66  2020-07-31          @  WAS   W  125    112  42   80  ...    20
# 66  67  67  2020-08-02        NaN  DAL   W  117    115  42   93  ...    33
# 67  68  68  2020-08-04          @  LAC   W  117    115  45   96  ...    23
#
#     FTA.1  FT%.1  ORB.1  TRB.1  AST.1  STL.1  BLK.1  TOV.1  PF.1
# ...
